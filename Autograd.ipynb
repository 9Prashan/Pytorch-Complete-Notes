# %% [markdown]
# Pytorch Features
#
# 1. Tensor Computations
# 2. GPU Acceleration
# 3. Dynamic Computation Graph
# 4. Automatic Differentiation
# 5. Distributed Training
# 6. Interoperability with other libraries

# %% [markdown]
# Differentiation in Pytorch

# %%
import torch
# Out:
# c:\Users\pst40\OneDrive\Desktop\Learnings\Pytorch\menv\Lib\site-packages\torch\_subclasses\functional_tensor.py:368: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\torch\csrc\utils\tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
x = torch.tensor(3.0, requires_grad=True)
b = torch.tensor(2.0, requires_grad=True)
y = x ** 2 + 2 * b * x + 1

# %%
b
# Out:
# tensor(2., requires_grad=True)

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(14., grad_fn=<AddBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(10.)

# %% [markdown]
# $Vectors ~ in ~ Autograd ~ - ~ Pytorch$

# %%
x = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)
y = (x ** 2).mean()

# %%
x
y
# Out:
# tensor([1., 4., 9.], grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
print(x.grad)
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %% [markdown]
# Exclusion from the DAG

# %%
x = torch.rand(5, 5)
y = torch.rand(5, 5)
z = torch.rand((5, 5), requires_grad=True)

a = x + y
print(f"Does `a` require gradients?: {a.requires_grad}")
b = x + z
print(f"Does `b` require gradients?: {b.requires_grad}")
# Out:
# Does `a` require gradients?: False
# Does `b` require gradients?: True

# %%
import torch

# Inputs
x = torch.tensor(6.7)  # Input feature
y = torch.tensor(0.0)  # True label (binary)

w = torch.tensor(1.0)  # Weight
b = torch.tensor(0.0)  # Bias

# %%
# Binary Cross-Entropy Loss for scalar
def binary_cross_entropy_loss(prediction, target):
    epsilon = 1e-8  # To prevent log(0)
    prediction = torch.clamp(prediction, epsilon, 1 - epsilon)
    return -(target * torch.log(prediction) + (1 - target) * torch.log(1 - prediction))

# %%
# Forward pass
z = w * x + b  # Weighted sum (linear part)
y_pred = torch.sigmoid(z)  # Predicted probability

# Compute binary cross-entropy loss
loss = binary_cross_entropy_loss(y_pred, y)

# %%
loss
# Out:
# tensor(6.7012)

# %%
# Derivatives:
# 1. dL/d(y_pred): Loss with respect to the prediction (y_pred)
dloss_dy_pred = (y_pred - y)/(y_pred*(1-y_pred))

# 2. dy_pred/dz: Prediction (y_pred) with respect to z (sigmoid derivative)
dy_pred_dz = y_pred * (1 - y_pred)

# 3. dz/dw and dz/db: z with respect to w and b
dz_dw = x  # dz/dw = x
dz_db = 1  # dz/db = 1 (bias contributes directly to z)

dL_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dL_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual Gradient of loss w.r.t weight (dw): {dL_dw}")
print(f"Manual Gradient of loss w.r.t bias (db): {dL_db}")
# Out:
# Manual Gradient of loss w.r.t weight (dw): 6.691762447357178
# Manual Gradient of loss w.r.t bias (db): 0.998770534992218

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

# %%
w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# %%
loss = binary_cross_entropy_loss(y_pred, y)
loss
# Out:
# tensor(6.7012)

# %%
loss.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 loss.backward()
#
# File ~\OneDrive\Desktop\Learnings\Pytorch\menv\Lib\site-packages\torch\_tensor.py:623, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     613 if has_torch_function_unary(self):
#     614     return handle_torch_function(
#     615         Tensor.backward,
#     616         (self,),
#    (...)    621         inputs=inputs,
#     622     )
# --> 623 torch.autograd.backward(
#     624     self, gradient, retain_graph, create_graph, inputs=inputs
#     625 )
#
# File ~\OneDrive\Desktop\Learnings\Pytorch\menv\Lib\site-packages\torch\autograd\__init__.py:395, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     390     retain_graph = create_graph
#     392 # The reason we repeat the same comment below is that
#     393 # some Python versions print out the first line of a multi-line function
#     394 # calls in the traceback and some print out the last line
# --> 395 _engine_run_backward(
#     396     tensors,
#     397     grad_tensors_,
#     398     retain_graph,
#     399     create_graph,
#     400     inputs_tuple,
#     401     allow_unreachable=True,
#     402     accumulate_grad=True,
#     403 )
#
# File ~\OneDrive\Desktop\Learnings\Pytorch\menv\Lib\site-packages\torch\autograd\graph.py:1072, in _engine_run_backward(t_outputs, *args, **kwargs)
#    1069 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#    1071 try:
# -> 1072     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#    1073         t_outputs, *args, **kwargs
#    1074     )  # Calls into the C++ engine to run the backward pass
#    1075 finally:
#    1076     if attach_logging_hooks:
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
print(w.grad)
print(b.grad)
# Out:
# None
# None

# %% [markdown]
# $ clearing ~ The~ Grad$

# %%
x.grad.zero_()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 x.grad.zero_()
#
# AttributeError: 'NoneType' object has no attribute 'zero_'
